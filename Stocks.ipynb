# %% [markdown]
# <a href="https://colab.research.google.com/github/PreethamSub/Scraping_stocks/blob/main/Stocks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#setup env
# !pip install selenium
# !apt-get update # to update ubuntu to correctly run apt install
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin

#imports
import sys
import bs4
from selenium import webdriver

#config stuff
sys.path.insert(0,'/usr/lib/chromium-browser/chromedriver')
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 995 kB 5.2 MB/s
# ...
#      |████████████████████████████████| 140 kB 51.3 MB/s
# ...
#      |████████████████████████████████| 384 kB 58.4 MB/s
# ...
#      |████████████████████████████████| 58 kB 6.3 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.12 which is incompatible.
# ...
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Hit:2 http://archive.ubuntu.com/ubuntu bionic InRelease
# ...

# %%
#get html and parse it
url = "https://www.stocklinedirect.com/intraday-tips.html"
browser = webdriver.Chrome('chromedriver',options=options)
browser.get(url)
html = browser.page_source
soup = bs4.BeautifulSoup(html,'html.parser')

#get table
table = soup.body.table

# %%
#iterate through table stuff
for row in table.findAll('tr'):
  for column in row.findAll('td'):
    print(column.getText().strip('\n'))
  print()
# Out:
# Buy
# SOUTHBANK
# The South Indian Bank Limited
# Very Bullish↑
# View details
#
# Buy
# PNB
# Punjab National Bank
# Bullish↑
# View details
#
# Buy
# BHEL
# Bharat Heavy Electricals Limited
# Very Bullish↑
# View details
#
# Buy
# ZOMATO
# ZOMATO
# Strong Uptrend↑
# View details
#
# Neutral
# IDEA
# Vodafone Idea Limited
# Neutral Downtrend↨
# View details
#
# Neutral
# YESBANK
# Yes Bank Limited
# Neutral Downtrend↨
# View details
#
# Sell
# IDFCFIRSTB
# IDFC First Bank Limited
# Strong Downtrend↓
# View details
#
# Sell
# SUZLON
# Suzlon Energy Limited
# Bearish↓
# View details
#
# Sell
# JPPOWER
# Jaiprakash Power Ventures Limited
# Downtrend↓
# View details
#
# Buy
# BANKBARODA
# Bank Of Baroda
# Uptrend↑
# View details
#
# Buy
# NHPC
# NHPC Limited
# Very Bullish↑
# View details
#
# Neutral
# TATASTEEL
# Tata Steel Limited
# Neutral Downtrend↨
# View details
#
# Buy
# CANBK
# Canara Bank
# Bullish↑
# View details
#
# Buy
# BANKINDIA
# Bank Of India
# Very Bullish↑
# ...

# %%
#create a custom data structure (if need be)
stock_data = dict()

for row in table.findAll('tr')[1:]:
  column = row.findAll('td')
  stock_data[column[1].getText()] = {
      'full_name':column[2].getText().strip('\n'), 
      'trend':column[3].getText(), 
      'suggestion':column[0].getText()
      }

# %%
#access the data like so:

print(
    stock_data['BHEL']['full_name'],
    stock_data['BHEL']['trend'],
    stock_data['BHEL']['suggestion'],
    sep='\n')
# Out:
# Bharat Heavy Electricals Limited
# Very Bullish↑
# Buy
